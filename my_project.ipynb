# %%
# CUDA-сумісний PyTorch (постав відповідну до твоєї CUDA версію з pytorch.org)
pip install --upgrade torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121

# Основні залежності
pip install "transformers>=4.44" accelerate bitsandbytes pillow pypdfium2 pyyaml tqdm

# Тулкіт від AllenAI (дає render_pdf_to_base64png і YAML-промпт)
pip install "olmocr>=0.4.0"

# %%
import torch, torchvision, torchaudio

print(torch.__version__, torch.version.cuda)
print(torchvision.__version__, torchaudio.__version__)
# Out:
# 2.7.1+cu126 12.6
# 0.22.1+cu126 2.7.1+cu126

# %%
pip install "bitsandbytes>=0.43.1"
